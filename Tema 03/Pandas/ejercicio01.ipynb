# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "2024_US_County_Level_Presidential_Results.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "phindolin/election-results-dataset",
  file_path,
)

print("First 5 records:", df.head())
# Out:
# First 5 records:   state_name  county_fips     county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama         1001  Autauga County      20447       7429        28139
# 1    Alabama         1003  Baldwin County      95144      24763       120973
# 2    Alabama         1005  Barbour County       5578       4120         9766
# 3    Alabama         1007     Bibb County       7563       1617         9230
# 4    Alabama         1009   Blount County      25271       2569        28024
#
#       diff   per_gop   per_dem  per_point_diff
# 0  13018.0  0.726643  0.264011        0.462632
# 1  70381.0  0.786490  0.204699        0.581791
# 2   1458.0  0.571165  0.421872        0.149293
# 3   5946.0  0.819393  0.175190        0.644204
# 4  22702.0  0.901763  0.091671        0.810091
