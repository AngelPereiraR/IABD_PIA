# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("swahajraza/world-cities-dataset")

# Set the path to the file you'd like to load
file_path = f"{path}/world_cities_data.csv"

# Load the CSV with the correct encoding
df = pd.read_csv(file_path, encoding='latin-1')

print("First 5 records:", df.head())
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/swahajraza/world-cities-dataset?dataset_version_number=1...
# 100%|██████████| 1.07M/1.07M [00:00<00:00, 1.92MB/s]
# Extracting files...
# First 5 records:    Unnamed: 0       city      lat       lng    country iso3  population  rank
# 0           0      Tokyo  35.6897  139.6922      Japan  JPN  37732000.0   1.0
# 1           1    Jakarta  -6.1750  106.8275  Indonesia  IDN  33756000.0   2.0
# 2           2      Delhi  28.6100   77.2300      India  IND  32226000.0   3.0
# 3           3  Guangzhou  23.1300  113.2600      China  CHN  26940000.0   4.0
# 4           4     Mumbai  19.0761   72.8775      India  IND  24973000.0   5.0
